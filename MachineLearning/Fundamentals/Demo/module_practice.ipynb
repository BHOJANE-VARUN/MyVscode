# %%
print("hello world")
# Out:
# hello world

# %%
import matplotlib as mt
import pandas as pd
dataframe1 = pd.read_csv('apple_quality.csv')
 
print(dataframe1.loc[0])
# Out:
# A_id                    0.0
# Size              -3.970049
# Weight            -2.512336
# Sweetness           5.34633
# Crunchiness       -1.012009
# Juiciness            1.8449
# Ripeness            0.32984
# Acidity        -0.491590483
# Quality                good
# Name: 0, dtype: object

# %%
print(dataframe1.Size)
# Out:
# 0      -3.970049
# 1      -1.195217
# 2      -0.292024
# 3      -0.657196
# 4       1.364217
#           ...
# 3996   -0.293118
# 3997   -2.634515
# 3998   -4.008004
# 3999    0.278540
# 4000         NaN
# Name: Size, Length: 4001, dtype: float64

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints, 'o')

# %%
fruitsiz = []
fruitweig = []

for x in range(0,300):
    fruitsiz.append(dataframe1.Size.loc[x])
    fruitweig.append(dataframe1.Weight.loc[x])
siz = np.array(fruitsiz)
weig = np.array(fruitweig)
plt.ylabel('Size of fruits')
plt.xlabel('Weight of fruits')

plt.plot(siz,weig,'o')
