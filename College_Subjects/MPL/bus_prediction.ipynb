# %%
import pandas as pd
df = pd.read_csv('stop_times.csv')
origin  = df[df['stop_id']==24]
dest = df[df['stop_id']==32]

# %%
from matplotlib import pyplot as plt
plt.scatter(origin['arrival_time'].values[:10],dest['arrival_time'].values[:10])
